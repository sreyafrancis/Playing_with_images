# %%
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
fd = open('apple.raw', 'rb')
rows = 480
cols = 640
f = np.fromfile(fd, dtype=np.uint8,count=rows*cols)
im = f.reshape((rows, cols)) #notice row, column format
fd.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-388ff5a92697> in <module>()
#       4 cols = 640
#       5 f = np.fromfile(fd, dtype=np.uint8,count=rows*cols)
# ----> 6 im = f.reshape((rows, cols)) #notice row, column format
#       7 fd.close()
#
# ValueError: total size of new array must be unchanged

# %%
import PIL

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-639cc4a728d3> in <module>()
#       4 # the 'F;16' informs the raw decoder that we are reading
#       5 # a little endian, unsigned integer 16 bit data.
# ----> 6 img = Image.fromstring('L', imgSize, rawData, 'raw', 'F;16')
#       7 img.save("foo.png")
#
# NameError: name 'Image' is not defined

# %%
import cv2
import numpy as np

#read the data from the file
with open('apple.raw', 'rb') as infile:
     buf = infile.read()

#use numpy to construct an array from the bytes
x = np.fromstring(buf, dtype='uint8')

#decode the array into an image
img = cv2.imdecode(x, cv2.IMREAD_UNCHANGED)

#show it
#plt.imshow(img)

# %%
from PIL import *

# %%
import Image

# %%
rawData = open("apple.raw", 'rb').read()
imgSize = (480,640)
# Use the PIL raw decoder to read the data.
# the 'F;16' informs the raw decoder that we are reading 
# a little endian, unsigned integer 16 bit data.
img = Image.fromstring('L', imgSize, rawData, 'raw', 'F;16')
img.save("f.png")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:6: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b35670b478e3> in <module>()
#       4 # the 'F;16' informs the raw decoder that we are reading
#       5 # a little endian, unsigned integer 16 bit data.
# ----> 6 img = Image.fromstring('L', imgSize, rawData, 'raw' )
#       7 img.save("foo.png")
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in fromstring(*args, **kw)
#    1836         stacklevel=2
#    1837     )
# -> 1838     return frombytes(*args, **kw)
#    1839
#    1840
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in frombytes(mode, size, data, decoder_name, *args)
#    1823
#    1824     im = new(mode, size)
# -> 1825     im.frombytes(data, decoder_name, args)
#    1826     return im
#    1827
#
# ...

# %%
os.getcwd()
# Out:
# '/home/tebd/DeepFruits'

# %%
path = '/home/tebd/DeepFruits/apple.raw'

# %%
import cv2.cv as cv

# %%
# Read rawImage from a file, but in reality will have it from TCPServer
f = open('apple.raw', "rb")
rawImage = f.read()
f.close()

# Convert rawImage to Mat
pilImage = Image.open(StringIO(rawImage))
npImage = np.array(pilImage)
matImage = cv.fromarray(npImage)

#show it
cv.NamedWindow('display')
cv.MoveWindow('display', 10, 10)
cv.ShowImage('display', matImage)
cv. WaitKey(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-37b553985eac> in <module>()
#       5
#       6 # Convert rawImage to Mat
# ----> 7 pilImage = Image.open(StringIO(rawImage))
#       8 npImage = np.array(pilImage)
#       9 matImage = cv.fromarray(npImage)
#
# TypeError: 'module' object is not callable

# %%
rawData = open("apple.raw" ,'rb').read()
imgSize = (360,480)
# Use the PIL raw decoder to read the data.
# the 'F;16' informs the raw decoder that we are reading 
# a little endian, unsigned integer 16 bit data.
image = Image.fromstring('F', imgSize, rawData, 'raw', 'F;16')
#image.convert('L').save('out.png')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:6: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-195587fe7354> in <module>()
#       4 # the 'F;16' informs the raw decoder that we are reading
#       5 # a little endian, unsigned integer 16 bit data.
# ----> 6 image = Image.fromstring('F', imgSize, rawData, 'raw', 'F;16')
#       7 #image.convert('L').save('out.png')
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in fromstring(*args, **kw)
#    1836         stacklevel=2
#    1837     )
# -> 1838     return frombytes(*args, **kw)
#    1839
#    1840
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in frombytes(mode, size, data, decoder_name, *args)
#    1823
#    1824     im = new(mode, size)
# -> 1825     im.frombytes(data, decoder_name, args)
# ...

# %%
import PIL
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
#import urllib.request

path =  '/home/tebd/DeepFruits/apple.raw'
#with urllib.request.urlopen('http://pastebin') as in_file:
hex_data = open("apple.raw" ,'rb').read()
#print(hex_data)
img = Image.frombuffer('RGB', (320,240), hex_data) #i have tried fromstring
draw = ImageDraw.Draw(img)
#font = ImageFont.truetype("arial.ttf",14)
font = ImageFont.load_default().font
draw.text((0, 220),"This is a test11",(255,255,0),font=font)
draw = ImageDraw.Draw(img)
img.save("a_test.jpg")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: RuntimeWarning: the frombuffer defaults may change in a future release; for portability, change the call to read:
#   frombuffer(mode, size, data, 'raw', mode, 0, 1)

# %%
import PIL
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
#import urllib.request

path =  '/home/tebd/DeepFruits/apple.raw'
#with urllib.request.urlopen('http://pastebin') as in_file:
hex_data = open("banana.raw" ,'rb').read()
#print(hex_data)
img = Image.frombuffer('RGB', (320,200), hex_data) #i have tried fromstring
draw = ImageDraw.Draw(img)
#font = ImageFont.truetype("Verdana.ttf",14)
font = ImageFont.load_default().font
draw.text((0, 220),"This is a test11",(255,255,0),font=font)
draw = ImageDraw.Draw(img)
img.save("banana.jpg")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: RuntimeWarning: the frombuffer defaults may change in a future release; for portability, change the call to read:
#   frombuffer(mode, size, data, 'raw', mode, 0, 1)

# %%
bn = cv2.imread('banana.jpg')
plt.imshow(bn)

# %%
bn_gr = cv2.imread('banana.jpg',0)
plt.imshow(bn_gr)

# %%
ret,th1 = cv2.threshold(bn_gr,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(bn_gr,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)

# %%
plt.imshow(th2)

# %%
plt.imshow(th1)

# %%
th3 = cv2.adaptiveThreshold(bn_gr,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

# %%
plt.imshow(th3)

# %%
import PIL
from PIL import Image
from PIL import ImageDraw
from PIL import ImageFont
#import urllib.request

path =  '/home/tebd/DeepFruits/apple.raw'
#with urllib.request.urlopen('http://pastebin') as in_file:
hex_data = open("orange.raw" ,'rb').read()
#print(hex_data)
img = Image.frombuffer('RGB', (320,200), hex_data) #i have tried fromstring
draw = ImageDraw.Draw(img)
#font = ImageFont.truetype("Verdana.ttf",14)
font = ImageFont.load_default().font
draw.text((0, 220),"This is a test11",(255,255,0),font=font)
draw = ImageDraw.Draw(img)
img.save("orange.png")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: RuntimeWarning: the frombuffer defaults may change in a future release; for portability, change the call to read:
#   frombuffer(mode, size, data, 'raw', mode, 0, 1)

# %%
bn_gr = cv2.imread('orange.png')
plt.imshow(bn_gr)

# %%
img = np.fromfile('apple.raw', "uint16")

# %%
img
# Out:
# array([38067, 38067, 38067, ..., 23454, 21499, 64957], dtype=uint16)

# %%
np.shape(img)
# Out:
# (130560,)

# %%
130560/2
# Out:
# 65280

# %%
im = np.reshape(img, (65280,2))

# %%
im
# Out:
# array([[38067, 38067],
#        [38067, 38067],
#        [38067, 38067],
#        ...,
#        [57213, 36855],
#        [42460, 23454],
#        [21499, 64957]], dtype=uint16)

# %%
import scipy.misc
scipy.misc.imsave('outfile.jpg', im)

# %%
path =  '/home/tebd/DeepFruits/apple.raw'
#with urllib.request.urlopen('http://pastebin') as in_file:
hex_data = open("orange.raw" ,'rb').read()
#print(hex_data)
img = Image.frombuffer('RGB', (320,200), hex_data) #i have tried fromstring
draw = ImageDraw.Draw(img)
#font = ImageFont.truetype("Verdana.ttf",14)
font = ImageFont.load_default().font
draw.text((0, 220),"This is a test11",(255,255,0),font=font)
draw = ImageDraw.Draw(img)
img.save("orange.png")

# %%
rawData = open("banana.raw", 'rb').read()
imgSize = (320,200)
# Use the PIL raw decoder to read the data.
# the 'F;16' informs the raw decoder that we are reading 
# a little endian, unsigned integer 16 bit data.
img = Image.fromstring('L', imgSize, rawData,  'RGB')
img.save("foo.png")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:6: DeprecationWarning: fromstring() is deprecated. Please call frombytes() instead.
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-136-a2aded6b3c19> in <module>()
#       4 # the 'F;16' informs the raw decoder that we are reading
#       5 # a little endian, unsigned integer 16 bit data.
# ----> 6 img = Image.fromstring('L', imgSize, rawData,  'RGB')
#       7 img.save("foo.png")
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in fromstring(*args, **kw)
#    1836         stacklevel=2
#    1837     )
# -> 1838     return frombytes(*args, **kw)
#    1839
#    1840
#
# /usr/lib/python2.7/dist-packages/PIL/Image.pyc in frombytes(mode, size, data, decoder_name, *args)
#    1823
#    1824     im = new(mode, size)
# -> 1825     im.frombytes(data, decoder_name, args)
#    1826     return im
#    1827
#
# ...

# %%
path =  '/home/tebd/DeepFruits/apple.raw'

# %%
import skimage 
from StringIO import StringIO

# %%
from StringIO import StringIO

with open(path) as f:
    img_data = f.read()
decoded_img_data = skimage.imread(StringIO(img_data))
print decoded_img_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-3ab321cf6c01> in <module>()
#       3 with open(path) as f:
#       4     img_data = f.read()
# ----> 5 decoded_img_data = skimage.imread(StringIO(img_data))
#       6 print decoded_img_data
#
# AttributeError: 'module' object has no attribute 'imread'

# %%
a = skimage.img_as_bool('banana.raw')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-6f6978508eac> in <module>()
# ----> 1 a = skimage.img_as_bool('banana.raw')
#
# /usr/lib/python2.7/dist-packages/skimage/util/dtype.pyc in img_as_bool(image, force_copy)
#     380
#     381     """
# --> 382     return convert(image, np.bool_, force_copy)
#
# /usr/lib/python2.7/dist-packages/skimage/util/dtype.pyc in convert(image, dtype, force_copy, uniform)
#      97
#      98     if not (dtype_in in _supported_types and dtype in _supported_types):
# ---> 99         raise ValueError("can not convert %s to %s." % (dtypeobj_in, dtypeobj))
#     100
#     101     def sign_loss():
#
# ValueError: can not convert |S10 to bool.

# %%
import rawpy
#import imageio

raw = rawpy.imread('apple.raw')
rgb = raw.postprocess()
#imageio.imsave('apple.tiff', rgb)
cv2.imwrite('apple1.jpeg',rgb)
# Out:
# LibRawNonFatalError('Unsupported file format or not RAW file',)
# LibRawNonFatalError('Request for nonexisting image number',)
# LibRawNonFatalError('Out of order call of libraw function',)
# False
