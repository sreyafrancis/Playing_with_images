# %%
import cv2
import os
import sys
from string import Template
import glob
from PIL import Image
from scipy import ndimage
from scipy.misc import toimage
import numpy as np

from matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

print 'Running this code from: ', os.getcwd()

# %%
image_path = "./gt_db/s03/01.jpg"
image = cv2.imread(image_path)
plt.imshow(image)
#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
flip = np.fliplr(image)
#plt.imshow(image)

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
faces = np.array([200,175,340,370])
faces = faces.reshape((1,4))

# %%
for( x, y, w, h ) in faces:
     cv2.rectangle(image, (x, y), (w, h), (255, 255, 0), 2)
     #outfname = "./gt_db/s03/02_chg.jpg"
     #cv2.imwrite(os.path.expanduser(outfname), image)

# %%
plt.imshow(flip)

# %%
for( x, y, w, h ) in faces:
     cv2.rectangle(image, (x, y), (w, h), (255, 255, 0), 2)

# %%
plt.imshow(image)
